# %%
# import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# import input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# remove diabetes outcome target from features data
y = diabetes_df['Outcome']
X = diabetes_df.drop(columns=['Outcome'])

# split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# preprocess numerical data for neural network

# create a StandardScaler instance
scaler = StandardScaler()

# fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## build the logistic regression model

# %% [markdown]
# ### logistic model does not need to scale the input data

# %%
# define the logistic regression model
log_classifier = LogisticRegression(solver='lbfgs', max_iter=200)

# train the model
log_classifier.fit(X_train, y_train)

# evaluate the model
y_pred = log_classifier.predict(X_test)
print(f' Logistic regression model accuracy: {accuracy_score(y_test, y_pred):.3f}')
# Out:
#  Logistic regression model accuracy: 0.729

# %% [markdown]
# ## build the basic neural network model

# %% [markdown]
# ### Compared to the 200 training iterations for our logistic regression model, we'll only train our neural network model through 50 epochs—this will limit the risk of overfitting our model.

# %%
# define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation='relu', input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# compile the Sequential model together and customize metrics
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 991us/step - loss: 0.8080 - accuracy: 0.6198
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7590 - accuracy: 0.6302
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7191 - accuracy: 0.6424
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.6458
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6557 - accuracy: 0.6615
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6305 - accuracy: 0.6684
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6100 - accuracy: 0.6736
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5915 - accuracy: 0.6823
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5749 - accuracy: 0.6962
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5609 - accuracy: 0.7066
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5488 - accuracy: 0.7118
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5380 - accuracy: 0.7153
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5283 - accuracy: 0.7240
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5200 - accuracy: 0.7344
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5123 - accuracy: 0.7378
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5055 - accuracy: 0.7413
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4997 - accuracy: 0.7500
# Epoch 18/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4949 - accuracy: 0.7535
# Epoch 19/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4897 - accuracy: 0.7587
# Epoch 20/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7622
# Epoch 21/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4816 - accuracy: 0.7726
# Epoch 22/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4781 - accuracy: 0.7760
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.7812
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7847
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.7830
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.7865
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4648 - accuracy: 0.7882
# Epoch 28/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.7847
# Epoch 29/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7882
# Epoch 30/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7882
# Epoch 31/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.7899
# Epoch 33/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4542 - accuracy: 0.7899
# Epoch 34/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7899
# Epoch 35/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4513 - accuracy: 0.7951
# Epoch 36/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.7951
# Epoch 37/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.7899
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7917
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7917
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7934
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7917
# Epoch 42/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.7951
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.7986
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7969
# Epoch 45/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4406 - accuracy: 0.7969
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4397 - accuracy: 0.7986
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.7986
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4384 - accuracy: 0.7951
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.7969
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7951
# 6/6 - 0s - loss: 0.4750 - accuracy: 0.7188 - 151ms/epoch - 25ms/step
# Loss: 0.4749723970890045, Accuracy: 0.71875
